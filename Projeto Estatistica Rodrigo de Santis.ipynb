# %% [markdown]
# Projeto - Módulo 6 - Estátistica
#
# Rodrigo de Santis
#
# Renata Luz
#
# Squad X

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import numpy as np 
import scipy as scp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
#df = pd.read_csv("Family Income and Expenditure.csv")
df=pd.read_csv("Family Income and Expenditure.csv").sample(n=100, random_state=13)

# %%
df.head(5)
# Out:
#        Total Household Income                 Region  Total Food Expenditure  \
# 26810                  223598         IVB - MIMAROPA                   67324
# 10000                  180600  VII - Central Visayas                   59069
# 15164                   73480    II - Cagayan Valley                   37053
# 1689                   256879       V - Bicol Region                  106028
# 12176                  159877      XI - Davao Region                   60856
#
#             Main Source of Income  Agricultural Household indicator  \
# 26810  Enterpreneurial Activities                                 1
# 10000     Other sources of Income                                 0
# 15164               Wage/Salaries                                 0
# 1689                Wage/Salaries                                 0
# 12176               Wage/Salaries                                 0
#
#        Bread and Cereals Expenditure  Total Rice Expenditure  \
# ...

# %%
df.columns
# Out:
# Index(['Total Household Income', 'Region', 'Total Food Expenditure',
#        'Main Source of Income', 'Agricultural Household indicator',
#        'Bread and Cereals Expenditure', 'Total Rice Expenditure',
#        'Meat Expenditure', 'Total Fish and  marine products Expenditure',
#        'Fruit Expenditure', 'Vegetables Expenditure',
#        'Restaurant and hotels Expenditure', 'Alcoholic Beverages Expenditure',
#        'Tobacco Expenditure', 'Clothing, Footwear and Other Wear Expenditure',
#        'Housing and water Expenditure', 'Imputed House Rental Value',
#        'Medical Care Expenditure', 'Transportation Expenditure',
#        'Communication Expenditure', 'Education Expenditure',
#        'Miscellaneous Goods and Services Expenditure',
#        'Special Occasions Expenditure', 'Crop Farming and Gardening expenses',
#        'Total Income from Entrepreneurial Acitivites', 'Household Head Sex',
#        'Household Head Age', 'Household Head Marital Status',
# ...

# %%
amostra_quali= df[['Household Head Sex','Main Source of Income','Household Head Job or Business Indicator','Household Head Highest Grade Completed']]

# %%
amostra_quanti = df[['Medical Care Expenditure','Education Expenditure','Total Number of Family members',
                 'Total Household Income','Total number of family members employed','Total Food Expenditure','Housing and water Expenditure',
                  'Household Head Age','House Floor Area','Number of Cellular phone']]

# %%
amostra_quanti
# Out:
#        Medical Care Expenditure  Education Expenditure  \
# 26810                      1510                      0
# 10000                     25730                   1026
# 15164                       660                      0
# 1689                       2219                    890
# 12176                       449                      0
# ...                         ...                    ...
# 3449                      23820                  53540
# 19270                       240                      0
# 29541                     12944                   2135
# 41326                      2891                    588
# 33428                       655                   2850
#
#        Total Number of Family members  Total Household Income  \
# 26810                               2                  223598
# 10000                               5                  180600
# 15164                               3                   73480
# ...

# %%
amostra_quanti.describe()
# Out:
#        Medical Care Expenditure  Education Expenditure  \
# count                100.000000             100.000000
# mean                5446.370000            6769.350000
# std                15787.558948           16819.405937
# min                    0.000000               0.000000
# 25%                  251.250000               0.000000
# 50%                  809.500000             660.000000
# 75%                 3206.000000            2155.000000
# max               134904.000000           92500.000000
#
#        Total Number of Family members  Total Household Income  \
# count                      100.000000            1.000000e+02
# mean                         4.490000            2.390318e+05
# std                          2.076784            2.863925e+05
# min                          1.000000            2.785100e+04
# 25%                          3.000000            9.695400e+04
# 50%                          4.000000            1.569625e+05
# ...

# %%
sns.heatmap(amostra_quanti.corr(),cmap='coolwarm')
plt.title('amostra_quanti.corr()')
plt.show()

# %%
sns.pairplot(amostra_quanti)

# %%
#Assimetria
#É o grau de desvio ou afastamento da simetria de uma distribuição.
#Quando a curva é simétrica, a média , a mediana e a moda coincidem num mesmo ponto, de ordenada máxima,
#havendo um perfeito equilíbrio na distribuição. Quando o equilíbrio não acontece, isto é, a média,
#a mediana e a moda recaem em pontos diferentes da distribuição, esta será assimétrica, enviesada à direita ou esquerda.

# %%
sns.jointplot(x='Total Food Expenditure', y='House Floor Area', data=amostra_quanti,kind='hex',height = 4 , ratio = 3)  
sns.jointplot(x='Total Household Income', y='House Floor Area', data=amostra_quanti, kind='hex',height = 5 , ratio = 4)

# %%
 #Calcule com 95% de confiança a média de dinheiro gasto com saúde e educação (colunas:
#Medical care Expenditure e Education expenditure)

# %%
# intervalo de confiança - Saúde
media = np.mean(amostra_quanti['Medical Care Expenditure'])
desvio_padrao = np.std(amostra_quanti['Medical Care Expenditure']/len(amostra_quanti['Medical Care Expenditure']))
norm.interval(0.95,loc=media, scale=desvio_padrao)
# Out:
# (5138.4905702753185, 5754.249429724681)

# %%
#intervalo de confiança - Educação
media = np.mean(amostra_quanti['Education Expenditure'])
desvio_padrao = np.std(amostra_quanti['Education Expenditure']/len(amostra_quanti['Education Expenditure']))
norm.interval(0.95,loc=media, scale=desvio_padrao)
# Out:
# (6441.348114130046, 7097.3518858699545)

# %%
amostra_quanti.describe()
# Out:
#        Medical Care Expenditure  Education Expenditure  \
# count                100.000000             100.000000
# mean                5446.370000            6769.350000
# std                15787.558948           16819.405937
# min                    0.000000               0.000000
# 25%                  251.250000               0.000000
# 50%                  809.500000             660.000000
# 75%                 3206.000000            2155.000000
# max               134904.000000           92500.000000
#
#        Total Number of Family members  Total Household Income  \
# count                      100.000000            1.000000e+02
# mean                         4.490000            2.390318e+05
# std                          2.076784            2.863925e+05
# min                          1.000000            2.785100e+04
# 25%                          3.000000            9.695400e+04
# 50%                          4.000000            1.569625e+05
# ...

# %%
#• Calcule se há diferença de média de número total de membros da família pelo sexo do chefe de família 
#(household head sex e total number of Family members) com 95% de confiança

# %%
df5 = df[['Total Number of Family members','Household Head Sex']]
df5.head()
# Out:
#        Total Number of Family members Household Head Sex
# 26810                               2               Male
# 10000                               5             Female
# 15164                               3               Male
# 1689                                6               Male
# 12176                               3               Male

# %%
df5.groupby(['Household Head Sex']).mean()
# Out:
#                     Total Number of Family members
# Household Head Sex
# Female                                    3.500000
# Male                                      4.769231

# %%
df5.groupby(['Household Head Sex']).count()
# Out:
#                     Total Number of Family members
# Household Head Sex
# Female                                          22
# Male                                            78

# %%
desvio = np.std(df5[df5['Household Head Sex']=='Female']['Total Number of Family members']/len(df5[df5['Household Head Sex']=='Female']))
norm.interval(0.95, loc=3.5, scale=desvio)
# Out:
# (3.3012435965937086, 3.6987564034062914)

# %%
desvio = np.std(df5[df5['Household Head Sex']=='Male']['Total Number of Family members']/len(df5[df5['Household Head Sex']=='Male']))
norm.interval(0.95, loc=4.7692, scale=desvio)
# Out:
# (4.720761581190497, 4.817638418809502)

# %%
#Calcule se há diferença de média total de renda da família(total household Income) de acordo com a fonte salarial( main source of income)
#Tarefa considere Enteroreneurial activities e other sources of income” como outros

# %%
df6 = df[['Main Source of Income','Total Household Income']]
df6['Main Source of Income'].unique()
# Out:
# array(['Enterpreneurial Activities', 'Other sources of Income',
#        'Wage/Salaries'], dtype=object)

# %%
df6['Main Source of Income'] = df6['Main Source of Income'].replace(['Enterpreneurial Activities'],'Other sources of Income' )
df6.groupby(['Main Source of Income']).count()
# Out:
# C:\Users\re_lu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                          Total Household Income
# Main Source of Income
# Other sources of Income                      63
# Wage/Salaries                                37

# %%
df6['Total Household Income'].mean()
# Out:
# 239031.77

# %%
desvio = np.std(df6[df6['Main Source of Income']=='Other sources of Income']['Total Household Income']/len(df6[df6['Main Source of Income']=='Other sources of Income']))
norm.interval(0.95, loc=4.7692, scale=desvio)
# Out:
# (-10573.055419643668, 10582.59381964367)

# %%
desvio = np.std(df6[df6['Main Source of Income']=='Wage/Salaries']['Total Household Income']/len(df6[df6['Main Source of Income']=='Wage/Salaries']))
norm.interval(0.95, loc=4.7692, scale=desvio)
# Out:
# (-7902.409687327013, 7911.948087327012)

# %%
#Diga se há relação entre o indicador se o chefe de família está empregado ou não( household
#head job or business indicator com a escolaridade household head highest grade)

# %%
amostra_quali
# Out:
#       Household Head Sex       Main Source of Income  \
# 26810               Male  Enterpreneurial Activities
# 10000             Female     Other sources of Income
# 15164               Male               Wage/Salaries
# 1689                Male               Wage/Salaries
# 12176               Male               Wage/Salaries
# ...                  ...                         ...
# 3449                Male               Wage/Salaries
# 19270             Female     Other sources of Income
# 29541             Female     Other sources of Income
# 41326             Female     Other sources of Income
# 33428               Male  Enterpreneurial Activities
#
#       Household Head Job or Business Indicator  \
# 26810                        With Job/Business
# 10000                        With Job/Business
# 15164                        With Job/Business
# 1689                         With Job/Business
# 12176                        With Job/Business
# ...

# %%
df7 = df[['Household Head Highest Grade Completed','Household Head Job or Business Indicator']]

# %%
df7['Household Head Highest Grade Completed'].unique()
# Out:
# array(['Grade 1', 'Grade 4', 'High School Graduate',
#        'Elementary Graduate', 'Business and Administration Programs',
#        'No Grade Completed', 'Grade 5', 'Grade 3', 'Second Year College',
#        'First Year College',
#        'Teacher Training and Education Sciences Programs',
#        'Computing/Information Technology Programs', 'Grade 2',
#        'Second Year High School', 'First Year High School',
#        'Health Programs', 'Agriculture, Forestry, and Fishery Programs'],
#       dtype=object)

# %%
df7 ['Household Head Highest Grade Completed'] = df7['Household Head Highest Grade Completed'].replace(['No Grade Completed','Grade 1', 'Grade 2','Grade 3', 'Grade 4','Grade 5'],'Fundamental incompleto').replace(['Elementary Graduate'],'Fundamental completo').replace(['First Year High School',  'Second Year High School'],'Medio incompleto').replace(['High School Graduate'],'Medio completo').replace(['First Year College', 'Second Year College'],'Superior incompleto').replace([ 'Business and Administration Programs',  'Teacher Training and Education Sciences Programs', 'Computing/Information Technology Programs', 'Agriculture, Forestry, and Fishery Programs','Health Programs'],'Superior completo')
# Out:
# C:\Users\re_lu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df7['Household Head Highest Grade Completed'].head(10)
# Out:
# 26810    Fundamental incompleto
# 10000    Fundamental incompleto
# 15164            Medio completo
# 1689     Fundamental incompleto
# 12176            Medio completo
# 21137      Fundamental completo
# 3691          Superior completo
# 35365    Fundamental incompleto
# 41435    Fundamental incompleto
# 27806      Fundamental completo
# Name: Household Head Highest Grade Completed, dtype: object

# %%
df7['Household Head Highest Grade Completed'].value_counts()
# Out:
# Fundamental incompleto    37
# Medio completo            23
# Fundamental completo      17
# Superior completo         11
# Superior incompleto        8
# Medio incompleto           4
# Name: Household Head Highest Grade Completed, dtype: int64

# %%
index_grade = df7['Household Head Highest Grade Completed'].replace(['Fundamental incompleto'],1).replace(['Fundamental completo'],2).replace(['Medio incompleto'], 3).replace(['Medio completo'], 4).replace(['Superior incompleto'],5).replace(['Superior completo'],6)

# %%
index_job = df7['Household Head Job or Business Indicator'].replace(['With Job/Business'], 1).replace(['No Job/Business'],0)

# %%
df7['index_grade'] = index_grade
df7['index_job'] = index_job
# Out:
# C:\Users\re_lu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\re_lu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df7.head(10)
# Out:
#       Household Head Highest Grade Completed  \
# 26810                 Fundamental incompleto
# 10000                 Fundamental incompleto
# 15164                         Medio completo
# 1689                  Fundamental incompleto
# 12176                         Medio completo
# 21137                   Fundamental completo
# 3691                       Superior completo
# 35365                 Fundamental incompleto
# 41435                 Fundamental incompleto
# 27806                   Fundamental completo
#
#       Household Head Job or Business Indicator  index_grade  index_job
# 26810                        With Job/Business            1          1
# 10000                        With Job/Business            1          1
# 15164                        With Job/Business            4          1
# 1689                         With Job/Business            1          1
# 12176                        With Job/Business            4          1
# ...

# %%
df7['index_grade'].corr(df7['index_job'])
# Out:
# 0.025617466018480757

# %%
df7.corr().style.format('{:.2}').background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style  type="text/css" >
#     #T_d7cacd78_e404_11ea_9a51_9502ce50c992row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d7cacd78_e404_11ea_9a51_9502ce50c992row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d7cacd78_e404_11ea_9a51_9502ce50c992row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d7cacd78_e404_11ea_9a51_9502ce50c992row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_d7cacd78_e404_11ea_9a51_9502ce50c992" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index_grade</th>        <th class="col_heading level0 col1" >index_job</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# Não existe relação entre a escolaridade e o status de trabalho atual.
